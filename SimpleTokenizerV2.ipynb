# %%
# Gunakan text asli dari raw_text
text1 = "Hello, do you like tea?"
text2 = "In the sunlit terraces of the palace."
text = " <|endoftext|> ".join((text1, text2))

tokenezer = SimpleTokenizerV2(vocab)
print("Text asli:")
print(repr(text))
print()
print("Hasil encode:")
encoded = tokenezer.encode(text)
print(encoded)
print()
print("Vocab check for special tokens:")
print(f"<|endoftext|> ada di vocab: {'<|endoftext|>' in vocab}")
print(f"<|unk|> ada di vocab: {'<|unk|>' in vocab}")
print()
print("-----"*100)
print("Hasil decode:")
print(tokenezer.decode(encoded))
# Out:
# Text asli:
# 'Hello, do you like tea? <|endoftext|> In the sunlit terraces of the palace.'
#
# Hasil encode:
# [732, 5, 732, 10, 732, 7]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Hasil decode:
# <|unk|>, <|unk|>? <|unk|>.
